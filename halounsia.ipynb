# %% [markdown]
# <a href="https://colab.research.google.com/github/salmanmfa2/data-science-2026/blob/main/halounsia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "Salman"
angkatan = 2026
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Salman","Informatika",2026))
# Out:
# Hello, Data Science!
# Halo, Salman angkatan 2026!
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# Salman | Informatika | 2026
